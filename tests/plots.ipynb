# %%
import matplotlib.pyplot as plt
from lapa.count import TailTesCounter

# %%
ttc = TailTesCounter('data/short_chr17.bam')

# %%
plt.figure(figsize=(3, 3), dpi=300)

ttc.plot_tail_len_dist()
# Out:
# 1539221it [00:02, 524684.27it/s]

# %%
plt.figure(figsize=(3, 3), dpi=300)

ttc = TailTesCounter('data/quantseq3_gm12878_chr17_rep1.bam')
ttc.plot_tail_len_dist()
# Out:
# 110635it [00:00, 247581.38it/s]

# %%
plt.figure(figsize=(3, 3), dpi=300)

ttc = TailTesCounter('data/quantseq3_gm12878_chr17_rep2.bam')
ttc.plot_tail_len_dist()
# Out:
# 106371it [00:00, 237131.28it/s]

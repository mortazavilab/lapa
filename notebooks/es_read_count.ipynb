# %%
import matplotlib.pyplot as plt
from lapa.count import PolyaTailCounter

# %%
ttc = PolyaTailCounter('../tests/data/short_chr17.bam', min_tail_len=1)

# %%
plt.figure(figsize=(3, 3), dpi=300)
ttc.plot_tail_len_dist()
# Out:
# - 0 reads counted...
# - 1539221 reads counted...

# %%
ttc = PolyaTailCounter('../tests/data/short_chr17.bam', min_tail_len=1, count_aligned=True)

# %%
plt.figure(figsize=(3, 3), dpi=300)
ttc.plot_tail_len_dist()
# Out:
# - 0 reads counted...
# - 1539221 reads counted...

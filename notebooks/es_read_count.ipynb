# %%
import matplotlib.pyplot as plt
from lapa.count import TailTesCounter

# %%
ttc = TailTesCounter('../data/results/quantseq/bam/ES_rep1/Aligned.sortedByCoord.out.bam', min_tail_len=1)

# %%
plt.figure(figsize=(3, 3), dpi=300)

ttc.plot_tail_len_dist()
# Out:
# 86640460it [13:00, 111015.05it/s]
